# %%
# importing required libraries
import mahotas
import numpy as np
from pylab import gray, imshow, show
import os
import matplotlib.pyplot as plt

# %%
# loading iamge
img = mahotas.imread('dog_image.jpg')

# fltering image
img = img[:, :, 0]

# showing image
imshow(img)
show()

# %%
# radius
radius = 10

# computing zernike moments
value = mahotas.features.zernike_moments(img, radius)

# printing value
print( f"zernike moments : \n {value}" )
# Out:
# zernike moments :
#  [0.31830989 0.0154539  0.00593615 0.01685118 0.00744525 0.01644534
#  0.01942096 0.01253311 0.0078843  0.01603397 0.01664191 0.00441885
#  0.00633834 0.01925401 0.02326376 0.00560661 0.01387539 0.0232162
#  0.02123579 0.0112721  0.02360292 0.00962155 0.00861026 0.01324012
#  0.00751148]
