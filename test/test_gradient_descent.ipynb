# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
def F(p):
    x = p[0]
    y = p[1]
    z = 4*x*x - 4*x*y + 2*y*y
    return z
pass

def DF(p) :
    x = p[0]
    y = p[1]
    dfx = 8*x -4*y
    dfy = -4*x + 4*y
    return np.array( [dfx, dfy] )
pass

# %%
delta = 0.025
w = 20
h = 20
x = np.arange(-w, w, delta)
y = np.arange(-h, h, delta)
X, Y = np.meshgrid(x, y)
Z = F([X, Y])

# %%
fig, ax = plt.subplots()
cs = ax.contour(X, Y, Z)
ax.clabel(cs, inline=1, fontsize=10)
ax.set_title('Contour Plot')
plt.show()

# %%
def gamma(p1, p0) :
    dp = p1 - p0
    df0 = DF(p0)
    df1 = DF(p1)
    df = df1 - df0
    r = np.transpose( dp ).dot( df )/np.linalg.norm( df, 2 )
    return r, df1

# %%
r = delta
p = np.array( [ w, h ] )
df = DF( p )

print( f"p={p}, r={r}, df={df}" )

f = F(p)
while f > 0.001 :
    p1 = p - r*df
    r, df = gamma( p1, p )
    p = p1
    f = F(p)
    print( f"p1={p1}, r={r}, df={df}, f={f}" )
# Out:
# p=[20 20], r=0.025, df=[80  0]
# p1=[18. 20.], r=1.7888543819998317, df=[64.  8.], f=656.0
# p1=[-96.48668045   5.68916494], r=97.69405543406049, df=[-794.65010336  408.70338157], f=39499.165770880696
# p1=[ 77536.10456788 -39922.20165004], r=87102.46226550834, df=[ 779977.6431432  -469833.22487169], f=39616602422.28821
# p1=[-6.79378957e+10  4.09235908e+10], r=79307715765.22131, df=[-7.07197529e+11  4.35445946e+11], f=3.2932761833777826e+22
# p1=[ 5.60862206e+22 -3.45342233e+22], r=6.586552924282603e+22, df=[ 5.86826658e+23 -3.62481776e+23], f=2.2715457998320362e+46
# p1=[-3.86516484e+46  2.38750540e+46], r=4.543091501813938e+46, df=[-4.04713403e+47  2.50106810e+47], f=1.0807076878082373e+94
# p1=[ 1.83865002e+94 -1.13625812e+94], r=2.1614153746254797e+94, df=[ 1.92542327e+95 -1.18996326e+95], f=2.446142475162095e+189
# p1=[-4.16163945e+189  2.57200488e+189], r=nan, df=[-4.35811351e+190  2.69345773e+190], f=inf
# p1=[nan nan], r=nan, df=[nan nan], f=nan
# <ipython-input-21-d613055498dc>:6: RuntimeWarning: invalid value encountered in double_scalars
#   r = np.transpose( dp ).dot( df )/np.linalg.norm( df, 2 )
# <ipython-input-20-f001a6725841>:4: RuntimeWarning: overflow encountered in double_scalars
#   z = 4*x*x - 4*x*y + 2*y*y
